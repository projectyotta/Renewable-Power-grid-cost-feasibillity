# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.AL-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.AK-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.AZ-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.AR-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.CA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.CO-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.CT-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.DE-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.DC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.ENC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.ESC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.FL-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.GA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.HI-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.ID-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.IL-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.IN-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.IA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.KS-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.KY-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.LA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.ME-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MD-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MI-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MAT-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MN-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MS-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MO-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MT-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.MTN-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NE-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NV-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NEW-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NH-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NJ-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NM-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NY-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.NC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.ND-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.OH-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.OK-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.OR-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.PCC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.PCN-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.PA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.RI-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.SAT-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.SC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.SD-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.TN-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.TX-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.US-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.UT-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.VT-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.VA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.WA-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.WNC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.WSC-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.WV-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.WI-ALL.M",
"https://www.eia.gov/opendata/qb.php?category=39&sdid=ELEC.REV.WY-ALL.M"]
print("done")
# Out:
# done

# %%
raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done amaze")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done amaze

# %%
frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#                                            Series Name  Period Frequency  \
# 0    Revenue from retail sales of electricity : Ala...  201707         M
# 1    Revenue from retail sales of electricity : Ala...  201706         M
# 2    Revenue from retail sales of electricity : Ala...  201705         M
# 3    Revenue from retail sales of electricity : Ala...  201704         M
# 4    Revenue from retail sales of electricity : Ala...  201703         M
# 5    Revenue from retail sales of electricity : Ala...  201702         M
# 6    Revenue from retail sales of electricity : Ala...  201701         M
# 7    Revenue from retail sales of electricity : Ala...  201612         M
# 8    Revenue from retail sales of electricity : Ala...  201611         M
# 9    Revenue from retail sales of electricity : Ala...  201610         M
# 10   Revenue from retail sales of electricity : Ala...  201609         M
# 11   Revenue from retail sales of electricity : Ala...  201608         M
# ...

# %%
result.to_csv('Electricity__Revenue_from_retail_sales_of_electricity.csv',sep=',',encoding='utf-8')
