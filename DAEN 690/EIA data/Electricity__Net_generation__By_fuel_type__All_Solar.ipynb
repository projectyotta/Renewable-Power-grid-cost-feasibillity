# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-AL-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-AK-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-AZ-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-AR-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-CA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-CO-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-CT-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-DE-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-DC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-ENC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-ESC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-FL-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-GA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-HI-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-ID-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-IL-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-IN-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-IA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-KS-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-KY-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-LA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-ME-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MD-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MI-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MAT-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MN-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MS-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MO-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MT-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-MTN-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NE-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NV-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NEW-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NH-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NJ-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NM-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NY-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-NC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-ND-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-OH-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-OK-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-OR-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-PCC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-PCN-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-PA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-RI-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-SAT-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-SC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-SD-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-TN-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-TX-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-US-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-UT-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-VT-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-VA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-WA-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-WNC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-WSC-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-WV-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-WI-99.M",
"https://www.eia.gov/opendata/qb.php?category=1718408&sdid=ELEC.GEN.TSN-WY-99.M"]
print("done")
# Out:
# done

# %%
raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done

# %%
frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#                                           Series Name  Period Frequency  \
# 0   Net generation : all solar : Alabama : all sec...  201707         M
# 1   Net generation : all solar : Alabama : all sec...  201706         M
# 2   Net generation : all solar : Alabama : all sec...  201705         M
# 3   Net generation : all solar : Alabama : all sec...  201704         M
# 4   Net generation : all solar : Alabama : all sec...  201703         M
# 5   Net generation : all solar : Alabama : all sec...  201702         M
# 6   Net generation : all solar : Alabama : all sec...  201701         M
# 7   Net generation : all solar : Alabama : all sec...  201612         M
# 8   Net generation : all solar : Alabama : all sec...  201611         M
# 9   Net generation : all solar : Alabama : all sec...  201610         M
# 10  Net generation : all solar : Alabama : all sec...  201609         M
# 11  Net generation : all solar : Alabama : all sec...  201608         M
# ...

# %%
result.to_csv('Electricity__Net_generation__By_fuel_type__All_Solar.csv',sep=',',encoding='utf-8')
