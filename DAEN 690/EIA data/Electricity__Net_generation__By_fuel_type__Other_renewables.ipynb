# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-AL-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-AK-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-AZ-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-AR-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-CA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-CO-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-CT-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-DE-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-DC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-ENC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-ESC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-FL-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-GA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-HI-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-ID-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-IL-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-IN-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-IA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-KS-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-KY-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-LA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-ME-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MD-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MI-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MAT-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MN-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MS-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MO-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MT-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-MTN-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NE-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NV-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NEW-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NH-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NJ-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NM-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NY-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-NC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-ND-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-OH-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-OK-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-OR-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-PCC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-PCN-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-PA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-RI-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-SAT-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-SC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-SD-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-TN-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-TX-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-US-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-UT-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-VT-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-VA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-WA-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-WNC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-WSC-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-WV-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-WI-99.M",
"https://www.eia.gov/opendata/qb.php?category=13&sdid=ELEC.GEN.AOR-WY-99.M"]
print("done")
# Out:
# done

# %%
raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done amaze")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done amaze

# %%
frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#                                            Series Name  Period Frequency  \
# 0    Net generation : other renewables (total) : Al...  201707         M
# 1    Net generation : other renewables (total) : Al...  201706         M
# 2    Net generation : other renewables (total) : Al...  201705         M
# 3    Net generation : other renewables (total) : Al...  201704         M
# 4    Net generation : other renewables (total) : Al...  201703         M
# 5    Net generation : other renewables (total) : Al...  201702         M
# 6    Net generation : other renewables (total) : Al...  201701         M
# 7    Net generation : other renewables (total) : Al...  201612         M
# 8    Net generation : other renewables (total) : Al...  201611         M
# 9    Net generation : other renewables (total) : Al...  201610         M
# 10   Net generation : other renewables (total) : Al...  201609         M
# 11   Net generation : other renewables (total) : Al...  201608         M
# ...

# %%
result.to_csv('Electricity__Net_generation__By_fuel_type__Other_renewables.csv',sep=',',encoding='utf-8')
print("I like dank memez and I cannot lie")
# Out:
# done

# %%
# Out:
# I like dank memez and I cannot lie
