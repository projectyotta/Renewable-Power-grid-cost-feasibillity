# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-AK-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-AZ-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-CA-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-CO-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-DE-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-ENC-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-ESC-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-HI-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-ID-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-IL-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-IN-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-IA-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-KS-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-ME-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MD-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MA-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MI-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MAT-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MN-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MO-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MT-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-MTN-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NE-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NV-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NEW-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NH-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NJ-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NM-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NY-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-NC-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-ND-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-OH-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-OK-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-OR-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-PCC-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-PCN-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-PA-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-RI-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-SAT-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-SD-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-TN-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-TX-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-US-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-UT-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-VT-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-WA-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-WNC-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-WSC-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-WV-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-WI-99.M",
"https://www.eia.gov/opendata/qb.php?category=14&sdid=ELEC.GEN.WND-WY-99.M"]
print("done")
# Out:
# done

# %%
raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done

# %%
frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#                                            Series Name  Period Frequency  \
# 0    Net generation : wind : Alaska : all sectors :...  201707         M
# 1    Net generation : wind : Alaska : all sectors :...  201706         M
# 2    Net generation : wind : Alaska : all sectors :...  201705         M
# 3    Net generation : wind : Alaska : all sectors :...  201704         M
# 4    Net generation : wind : Alaska : all sectors :...  201703         M
# 5    Net generation : wind : Alaska : all sectors :...  201702         M
# 6    Net generation : wind : Alaska : all sectors :...  201701         M
# 7    Net generation : wind : Alaska : all sectors :...  201612         M
# 8    Net generation : wind : Alaska : all sectors :...  201611         M
# 9    Net generation : wind : Alaska : all sectors :...  201610         M
# 10   Net generation : wind : Alaska : all sectors :...  201609         M
# 11   Net generation : wind : Alaska : all sectors :...  201608         M
# ...

# %%
result.to_csv('Electricity__Net_generation__By_fuel_type__Wind.csv',sep=',',encoding='utf-8')

# %%
for i in range(0,len(state_list)):
    raw_[i]="content"+[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-de9df2ed66dc> in <module>()
#       1 for i in range(0,len(state_list)):
# ----> 2     raw_[i]="content"+[i]
#
# TypeError: must be str, not list

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dc0ea82142cb> in <module>()
# ----> 1 df[1]
#
# NameError: name 'df' is not defined
