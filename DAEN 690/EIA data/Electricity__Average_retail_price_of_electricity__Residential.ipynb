# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.AL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.AK-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.AZ-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.AR-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.CA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.CO-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.CT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.DE-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.DC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.ENC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.ESC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.FL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.GA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.HI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.ID-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.IL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.IN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.IA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.KS-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.KY-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.LA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.ME-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MD-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MAT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MS-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MO-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.MTN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NE-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NV-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NEW-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NH-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NJ-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NM-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NY-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.NC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.ND-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.OH-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.OK-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.OR-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.PCC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.PCN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.PA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.RI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.SAT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.SC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.SD-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.TN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.TX-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.US-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.UT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.VT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.VA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.WA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.WNC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.WSC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.WV-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.WI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1012&sdid=ELEC.PRICE.WY-RES.M"]
print("done")
# Out:
# done

# %%
raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done

# %%
frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#                                            Series Name  Period Frequency  \
# 0    Average retail price of electricity : Alabama ...  201707         M
# 1    Average retail price of electricity : Alabama ...  201706         M
# 2    Average retail price of electricity : Alabama ...  201705         M
# 3    Average retail price of electricity : Alabama ...  201704         M
# 4    Average retail price of electricity : Alabama ...  201703         M
# 5    Average retail price of electricity : Alabama ...  201702         M
# 6    Average retail price of electricity : Alabama ...  201701         M
# 7    Average retail price of electricity : Alabama ...  201612         M
# 8    Average retail price of electricity : Alabama ...  201611         M
# 9    Average retail price of electricity : Alabama ...  201610         M
# 10   Average retail price of electricity : Alabama ...  201609         M
# 11   Average retail price of electricity : Alabama ...  201608         M
# ...

# %%
result.to_csv('Electricity__Average_retail_price_of_electricity__Residential.csv',sep=',',encoding='utf-8')
