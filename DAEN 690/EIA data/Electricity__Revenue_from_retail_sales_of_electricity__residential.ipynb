# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.AL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.AK-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.AZ-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.AR-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.CA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.CO-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.CT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.DE-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.DC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.ENC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.ESC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.FL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.GA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.HI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.ID-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.IL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.IN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.IA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.KS-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.KY-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.LA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.ME-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MD-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MAT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MS-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MO-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.MTN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NE-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NV-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NEW-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NH-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NJ-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NM-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NY-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.NC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.ND-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.OH-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.OK-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.OR-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.PCC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.PCN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.PA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.RI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.SAT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.SC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.SD-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.TN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.TX-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.US-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.UT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.VT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.VA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WNC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WSC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WV-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WY-RES.M"]
print("done with loading links")

raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done amaze")

frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("frames concat done")

result

result.to_csv('Electricity__Revenue_from_retail_sales_of_electricity__residential.csv',sep=',',encoding='utf-8')
print("I like dank memez and I cannot lie")
# Out:
# done with loading links
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done amaze
# frames concat done
# I like dank memez and I cannot lie
