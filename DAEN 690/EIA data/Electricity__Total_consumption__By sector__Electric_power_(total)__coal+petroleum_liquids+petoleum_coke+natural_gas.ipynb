# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-AL-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-AK-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-AZ-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-AR-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-CA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-CO-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-CT-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-DE-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-ENC-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-ESC-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-FL-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-GA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-HI-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-IL-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-IN-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-IA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-KS-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-KY-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-LA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-ME-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MD-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MI-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MN-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MS-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MO-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MT-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-MTN-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NE-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NV-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NEW-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NH-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NJ-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NM-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NY-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-NC-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-ND-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-OH-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-OK-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-OR-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-PCC-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-PCN-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-PA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-SAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-SC-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-SD-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-TN-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-TX-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-US-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-UT-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-VA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-WA-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-WNC-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-WSC-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-WV-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-WI-98.M",
"https://www.eia.gov/opendata/qb.php?category=870&sdid=ELEC.CONS_TOT.COW-WY-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-AL-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-AK-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-AZ-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-AR-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-CA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-CO-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-CT-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-DE-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-DC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-ENC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-ESC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-FL-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-GA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-HI-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-ID-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-IL-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-IN-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-IA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-KS-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-KY-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-LA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-ME-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MD-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MI-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MN-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MS-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MO-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MT-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-MTN-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NE-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NV-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NEW-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NH-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NJ-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NM-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NY-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-NC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-ND-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-OH-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-OK-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-OR-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-PCC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-PCN-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-PA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-RI-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-SAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-SC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-SD-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-TN-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-TX-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-US-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-UT-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-VT-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-VA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-WA-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-WNC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-WSC-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-WV-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-WI-98.M",
"https://www.eia.gov/opendata/qb.php?category=871&sdid=ELEC.CONS_TOT.PEL-WY-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-CA-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-ENC-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-ESC-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-FL-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-IL-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-IN-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-IA-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-KS-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-KY-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-LA-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-MI-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-MAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-MN-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-MO-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-MT-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-MTN-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-NY-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-OH-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-PCC-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-PA-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-SAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-SC-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-TX-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-US-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-WNC-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-WSC-98.M",
"https://www.eia.gov/opendata/qb.php?category=872&sdid=ELEC.CONS_TOT.PC-WI-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-AL-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-AK-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-AZ-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-AR-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-CA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-CO-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-CT-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-DE-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-DC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-ENC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-ESC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-FL-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-GA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-ID-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-IL-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-IN-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-IA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-KS-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-KY-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-LA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-ME-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MD-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MI-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MN-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MS-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MO-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MT-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-MTN-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NE-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NV-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NEW-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NH-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NJ-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NM-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NY-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-NC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-ND-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-OH-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-OK-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-OR-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-PCC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-PCN-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-PA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-RI-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-SAT-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-SC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-SD-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-TN-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-TX-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-US-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-UT-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-VT-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-VA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-WA-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-WNC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-WSC-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-WV-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-WI-98.M",
"https://www.eia.gov/opendata/qb.php?category=873&sdid=ELEC.CONS_TOT.NG-WY-98.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WSC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WV-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1007&sdid=ELEC.REV.WY-RES.M"]
print("done with loading links")

raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done amaze")

frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("frames concat done")

result

result.to_csv('Electricity__Total_consumption__By sector__Electric_power_(total)__coal+petroleum_liquids+petoleum_coke+natural_gas.csv',sep=',',encoding='utf-8')
print("I like dank memez and I cannot lie")
# Out:
# done with loading links
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...
