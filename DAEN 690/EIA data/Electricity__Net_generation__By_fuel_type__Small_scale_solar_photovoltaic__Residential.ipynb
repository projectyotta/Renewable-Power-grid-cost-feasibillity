# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-AL-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-AK-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-AZ-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-AR-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-CA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-CO-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-CT-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-DE-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-DC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-ENC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-ESC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-FL-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-GA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-HI-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-ID-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-IL-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-IN-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-IA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-KS-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-KY-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-LA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-ME-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MD-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MI-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MAT-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MN-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MS-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MO-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MT-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-MTN-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NE-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NV-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NEW-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NH-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NJ-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NM-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NY-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-NC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-ND-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-OH-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-OK-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-OR-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-PCC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-PCN-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-PA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-RI-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-SAT-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-SC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-SD-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-TN-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-TX-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-US-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-UT-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-VT-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-VA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-WA-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-WNC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-WSC-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-WV-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-WI-8.M",
"https://www.eia.gov/opendata/qb.php?category=1737314&sdid=ELEC.GEN.DPV-WY-8.M"]
print("done")
# Out:
# done

# %%
raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done amaze")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done amaze

# %%
frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#                                           Series Name  Period Frequency  \
# 0   Net generation : small-scale solar photovoltai...  201707         M
# 1   Net generation : small-scale solar photovoltai...  201706         M
# 2   Net generation : small-scale solar photovoltai...  201705         M
# 3   Net generation : small-scale solar photovoltai...  201704         M
# 4   Net generation : small-scale solar photovoltai...  201703         M
# 5   Net generation : small-scale solar photovoltai...  201702         M
# 6   Net generation : small-scale solar photovoltai...  201701         M
# 7   Net generation : small-scale solar photovoltai...  201612         M
# 8   Net generation : small-scale solar photovoltai...  201611         M
# 9   Net generation : small-scale solar photovoltai...  201610         M
# 10  Net generation : small-scale solar photovoltai...  201609         M
# 11  Net generation : small-scale solar photovoltai...  201608         M
# ...

# %%
result.to_csv('Electricity__Net_generation__By_fuel_type__Small_scale_solar_photovoltaic__Residential.csv',sep=',',encoding='utf-8')
