# %%
import pandas as pd 
import requests
state_list=["https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.AL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.AK-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.AZ-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.AR-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.CA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.CO-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.CT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.DE-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.DC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.ENC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.ESC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.FL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.GA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.HI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.ID-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.IL-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.IN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.IA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.KS-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.KY-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.LA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.ME-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MD-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MAT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MS-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MO-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.MTN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NE-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NV-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NEW-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NH-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NJ-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NM-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NY-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.NC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.ND-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.OH-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.OK-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.OR-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.PCC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.PCN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.PA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.RI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.SAT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.SC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.SD-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.TN-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.TX-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.US-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.UT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.VT-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.VA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.WA-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.WNC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.WSC-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.WV-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.WI-RES.M",
"https://www.eia.gov/opendata/qb.php?category=1002&sdid=ELEC.SALES.WY-RES.M"]
print("done")
# Out:
# done

# %%
raw={}
df={}
for i in range(0,len(state_list)):
    raw[i]=pd.read_html(state_list[i])
    df[i]=list(raw[i])
    df[i]=pd.DataFrame(df[i][0])
    print("done")
print("wow done amaze")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# wow done amaze

# %%
frames=[df[i] for i in range(0,len(state_list))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#                                            Series Name  Period Frequency  \
# 0    Retail sales of electricity : Alabama : reside...  201707         M
# 1    Retail sales of electricity : Alabama : reside...  201706         M
# 2    Retail sales of electricity : Alabama : reside...  201705         M
# 3    Retail sales of electricity : Alabama : reside...  201704         M
# 4    Retail sales of electricity : Alabama : reside...  201703         M
# 5    Retail sales of electricity : Alabama : reside...  201702         M
# 6    Retail sales of electricity : Alabama : reside...  201701         M
# 7    Retail sales of electricity : Alabama : reside...  201612         M
# 8    Retail sales of electricity : Alabama : reside...  201611         M
# 9    Retail sales of electricity : Alabama : reside...  201610         M
# 10   Retail sales of electricity : Alabama : reside...  201609         M
# 11   Retail sales of electricity : Alabama : reside...  201608         M
# ...

# %%
result.to_csv('Electricity__Retail_sales_of_electricity__Residential.csv',sep=',',encoding='utf-8')
